# %%
import numpy as np
import pandas as pd

# %%
n = 1500
df = {
      'X_0': np.random.triangular(1.0, 2.0, 4.0, n),
      'X_1': np.random.triangular(2.0, 4.0, 6.0, n),
      'X_2': np.random.triangular(4.0, 5.0, 8.0, n)
     }

df = pd.DataFrame(df)
df
# Out:
#             X_0       X_1       X_2
# 0      1.284419  4.987130  4.355947
# 1      2.588769  5.012467  4.958100
# 2      1.905634  5.250776  6.262684
# 3      2.939066  5.339990  6.315121
# 4      1.386177  5.476008  5.813294
# ...         ...       ...       ...
# 29995  1.952260  3.886438  6.698841
# 29996  2.951142  3.958642  5.590405
# 29997  1.466103  4.079105  7.446109
# 29998  2.915426  3.608895  4.739421
# 29999  2.090249  3.284729  5.956355
#
# [30000 rows x 3 columns]

# %%
F (ultima atividade) = [# durações] # coluna do dataframe df

# Lista das colunas que você quer plotar
colunas_para_plotar = ['caminho critico'] = 'A-C-B-D' , ["acumulado final"] = a+b+c+d
                        # média
                        # desvio padrão
                        #


# Loop para gerar histogramas
for coluna in colunas_para_plotar:
    plt.figure(figsize=(8, 4))  # Tamanho da figura
    plt.hist(amostras[coluna], bins=50, color='skyblue', edgecolor='black', alpha=0.7)
    plt.title(f"Histograma de '{coluna}'")
    plt.xlabel(coluna)
    plt.ylabel("Frequência")
    plt.grid(axis='y', alpha=0.3)
    plt.show()  # Mostra um gráfico por vez
